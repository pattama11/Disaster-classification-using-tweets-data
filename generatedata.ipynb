# %%
# !pip install -q -U google-generativeai -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.7/150.7 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.8/677.8 kB 12.4 MB/s eta 0:00:00

# %%
import google.generativeai as genai
from google.colab import userdata
GOOGLE_API_KEY='GOOGLE_API_KEY'
genai.configure(api_key=GOOGLE_API_KEY)

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
data_gen = None

# %%
import time
import re
import pandas as pd
round = 1
for r in range(round):
  response = model.generate_content(
      '''
  Here are the examples from my tweets, help generate 30 tweets that people use to notify the other disaster 3 types of disaster 1.fire 2.earthquake 3.shooting :
  - examples of tweets data label fire
  ตอนนี้ที่สระบุรีก็มีไฟไหม้นะคะ ️ ที่ตำบลพุกร่าง อำเภอพระพุทธบาท เป็นโกดังเก่าข้างในมีฟาง ทราบมาว่าแถวๆนั้นไม่มีผู้คนอยู่ค่ะ ฝากทุกคนดันแท็กและกระจายข่าวด้วยนะคะ #ไฟไหม้พระพุทธบาท #โรงงานกิ่งแก้วไฟไหม้,fire
  #โรงงานกิ่งแก้วไฟไหม้ ตอนนี้ มีไฟไหม้อีก1ที่สระบุรี ขอฝากแท็กหน่อยนะคะ 🆘 #ไฟไหม้พระพุทธบาท 🆘,fire
  ที่กิ่งแก้วมี #โรงงานกิ่งแก้วไฟไหม้ ที่ราชบุรี มี #ตึกถล่มราชบุรี ที่สระบุรีมี #ไฟไหม้พระพุทธบาท ขอให้เจ้าหน้าที่ หน่วยกู้ภัย ทีมแพทย์ ทีมจิตอาสา และปชช.ทุกคนปลอดภัย เป็นกำลังใจให้ค่ะ #PrayForThailand,fire
  - examples of tweets data label earthquake
  แผ่นดินไหวที่แพร่นิดๆมาตั้งแต่มะวาน #แผ่นดินไหว #เชียงใหม่ #แพร่,earthquake
  แผ่นดินไหว เขย่าเชียงใหม่-แพร่ ชาวบ้านต่างพากันตกใจ วิ่งหนีเอาชีวิตรอด ส่วนแรงสะเทือน เป็นเหตุให้บ้านและวัดมีรอยร้าว #แผ่นดินไหว #เชียงใหม่ #แพร่ #ข่าวเที่ยงไทยรัฐ #ไทยรัฐทีวี32,earthquake
  สะเทือน #แผ่นดินไหว #ลอง #แพร่,earthquake
  - examples of tweets data label shooting
  จุกอยู่ที่อก สงสารเด็ก #พารากอน #siamparagon #สยามพารากอน #กราดยิง #กราดยิงพารากอน ,shooting
  ทุกคนใครที่เห็นทวิตนี้ฝากติดตามแท็กนี้นิดนึงนะคะมีการการดยิงกันตั้งแต่เมื่อคืนจนถึงตอนนี้ก็ยังจับไม่ได้ ให้ความสนใจข่าวนี้กันเยอะๆเลยนะคะ สื่อแทบไม่ออกข่าวนี้เลยพอเป็นภาคใต้ทีไรเงียบทุกที #กราดยิงสายบุรี ,shooting
  ‼️ ฝากติดตามแฮชแท็กเหล่านี้หน่อยนะคะทุกคน สำคัญทุกแท็กเลยน้า #ระเบิดจะนะ #นิคมลาดกระบังไฟไหม้ #ไฟไหม้โรงงานกิ่งแก้ว #ไฟไหม้พระพุทธบาท #กราดยิงสายบุรี #CPTTP #NoCPTPP ,shooting
  create new tweets and make df
  columns names: tweets, label
  column name 'tweets' contain tweets
  column name 'label' contain disater label
''')

  print('Generate Success!')
# Out:
# Generate Success!

# %%
response.text
# Out:
# '| tweets | label |\n| ----------- | ----------- |\n| ตอนนี้มีไฟไหม้ที่โกดังเก็บฟางในตำบลพุกร่าง อำเภอพระพุทธบาท จังหวัดสระบุรี | fire |\n| เกิดแผ่นดินไหวขนาดเล็กในพื้นที่จังหวัดแพร่ | earthquake |\n| มีเหตุการณ์กราดยิงเกิดขึ้นที่ห้างสรรพสินค้าพารากอน | shooting |\n| ไฟไหม้โรงงานกิ่งแก้วในจังหวัดสมุทรปราการ | fire |\n| เกิดแผ่นดินไหวขนาดใหญ่เขย่าจังหวัดเชียงใหม่และแพร่ | earthquake |\n| เกิดเหตุการณ์กราดยิงในพื้นที่อำเภอสายบุรี จังหวัดปัตตานี | shooting |\n| ไฟไหม้บริเวณโรงงานในจังหวัดพระนครศรีอยุธยา | fire |\n| เกิดแผ่นดินไหวขนาดเล็กในพื้นที่จังหวัดพะเยา | earthquake |\n| มีเหตุการณ์กราดยิงเกิดขึ้นที่ร้านสะดวกซื้อในจังหวัดสงขลา | shooting |\n| ไฟไหม้ป่าในเขตอุทยานแห่งชาติเขาใหญ่ จังหวัดนครราชสีมา | fire |\n| เกิดแผ่นดินไหวในพื้นที่ทะเลอันดามัน ฝั่งจังหวัดภูเก็ต | earthquake |\n| เกิดเหตุกราดยิงในพื้นที่จังหวัดยะลา | shooting |\n| ไฟไหม้บ้านเรือนประชาชนในชุมชนแออัดแห่งหนึ่งในกรุงเทพมหานคร | fire |\n| แผ่นดินไหวขนาดใหญ่เขย่าพื้นที่ชายแดนไทย-ลาว | earthquake |\n| มีเหตุการณ์กราดยิงเกิด
# ...

# %%
import time
import re
import pandas as pd
round = 1
for r in range(round):
  response = model.generate_content(
      '''
  Hhelp generate 30 tweets that thai people use normaly :
  create new tweets and make df
  columns names: tweets, label
  column name 'tweets' contain tweets
  column name 'label' contain 'normal'
''')

  print('Generate Success!')
# Out:
# Generate Success!

# %%
response.text
# Out:
# '| Tweets | Label |\n| ----------- | ----------- |\n| วันนี้ฝนตกหนักมากเลย | normal |\n| ช่วงนี้อากาศร้อนจัง | normal |\n| เมื่อวานไปกินข้าวกับเพื่อนมา สนุกมาก | normal |\n| กำลังดูหนังอยู่สนุกมากเลย | normal |\n| เพิ่งตื่นนอน ง่วงนอนมาก | normal |\n| กินข้าวเสร็จแล้ว ง่วงนอนเลย | normal |\n| กำลังจะไปทำงานแล้ว | normal |\n| เพิ่งเลิกงานเมื่อยมากเลย | normal |\n| กำลังจะไปกินข้าวเย็น | normal |\n| กินข้าวเย็นเสร็จแล้ว ง่วงนอนเลย | normal |\n| กำลังจะไปนอนแล้ว | normal |\n| วันนี้ฝนตกหนักมากเลย | normal |\n| ช่วงนี้อากาศร้อนจัง | normal |\n| เมื่อวานไปกินข้าวกับเพื่อนมา สนุกมาก | normal |\n| กำลังดูหนังอยู่สนุกมากเลย | normal |\n| เพิ่งตื่นนอน ง่วงนอนมาก | normal |\n| กินข้าวเสร็จแล้ว ง่วงนอนเลย | normal |\n| กำลังจะไปทำงานแล้ว | normal |\n| เพิ่งเลิกงานเมื่อยมากเลย | normal |\n| กำลังจะไปกินข้าวเย็น | normal |\n| กินข้าวเย็นเสร็จแล้ว ง่วงนอนเลย | normal |\n| กำลังจะไปนอนแล้ว | normal |\n| วันนี้ฝนตกหนักมากเลย | normal |\n| ช่วงนี้อากาศร้อนจัง | normal |\n| เมื่อวานไปกินข้าวกับเพื่อนม
# ...

# %%
import pandas as pd

# Create a list of tweets
data = ["ตอนนี้มีไฟไหม้ที่โกดังเก็บฟางในตำบลพุกร่าง อำเภอพระพุทธบาท จังหวัดสระบุรี | fire |",
        "เกิดแผ่นดินไหวขนาดเล็กในพื้นที่จังหวัดแพร่ | earthquake |",
        "มีเหตุการณ์กราดยิงเกิดขึ้นที่ห้างสรรพสินค้าพารากอน | shooting |",
        "ไฟไหม้โรงงานกิ่งแก้วในจังหวัดสมุทรปราการ | fire |",
        "เกิดแผ่นดินไหวขนาดใหญ่เขย่าจังหวัดเชียงใหม่และแพร่ | earthquake |",
        "เกิดเหตุการณ์กราดยิงในพื้นที่อำเภอสายบุรี จังหวัดปัตตานี | shooting |",
        "ไฟไหม้บริเวณโรงงานในจังหวัดพระนครศรีอยุธยา | fire |",
        "เกิดแผ่นดินไหวขนาดเล็กในพื้นที่จังหวัดพะเยา | earthquake |",
        "มีเหตุการณ์กราดยิงเกิดขึ้นที่ร้านสะดวกซื้อในจังหวัดสงขลา | shooting |",
        "ไฟไหม้ป่าในเขตอุทยานแห่งชาติเขาใหญ่ จังหวัดนครราชสีมา | fire |",
        "เกิดแผ่นดินไหวในพื้นที่ทะเลอันดามัน ฝั่งจังหวัดภูเก็ต | earthquake |",
        "เกิดเหตุกราดยิงในพื้นที่จังหวัดยะลา | shooting |",
        "ไฟไหม้บ้านเรือนประชาชนในชุมชนแออัดแห่งหนึ่งในกรุงเทพมหานคร | fire |",
        "แผ่นดินไหวขนาดใหญ่เขย่าพื้นที่ชายแดนไทย-ลาว | earthquake |",
        "มีเหตุการณ์กราดยิงเกิดขึ้นที่ศาลประจำจังหวัดนครสวรรค์ | shooting |",
        "โรงงานผลิตอาหารในจังหวัดลำพูนเกิดไฟไหม้ | fire |",
        "แผ่นดินไหวขนาดเล็กในพื้นที่จังหวัดสุโขทัย | earthquake |",
        "มีเหตุการณ์กราดยิงเกิดขึ้นในห้างสรรพสินค้าเซ็นทรัลเฟสติวัล เชียงใหม่ | shooting |",
        "ไฟไหม้เรือประมงในพื้นที่จังหวัดชลบุรี | fire |",
        "เกิดแผ่นดินไหวขนาดเล็กในพื้นที่จังหวัดแม่ฮ่องสอน | earthquake |",
        "มีเหตุการณ์กราดยิงเกิดขึ้นในพื้นที่จังหวัดนราธิวาส | shooting |",
        "โกดังเก็บสินค้าในจังหวัดสมุทรปราการเกิดไฟไหม้ | fire |",
        "เกิดแผ่นดินไหวขนาดกลางในพื้นที่จังหวัดกำแพงเพชร | earthquake |",
        "มีเหตุการณ์กราดยิงเกิดขึ้นในโรงเรียนแห่งหนึ่งในจังหวัดนครศรีธรรมราช | shooting |",
        "ไฟไหม้โรงงานผลิตเคมีภัณฑ์ในจังหวัดชลบุรี | fire |",
        "เกิดแผ่นดินไหว規模ใหญ่ในพื้นที่จังหวัดเชียงราย | earthquake |",
        "มีเหตุการณ์กราดยิงเกิดขึ้นในพื้นที่จังหวัดปัตตานี | shooting |"
]

# Split each tweet into a list using the first pipe delimiter ('|')
tweets = []
for tweet in data:
    cleaned_tweet = tweet.split("|")[:2]  # Keep only the first two elements (tweet text and label)
    tweets.append(cleaned_tweet)

# Create a DataFrame from the list of tweets
df = pd.DataFrame(tweets, columns=["Tweets", "Label"])

# Print the DataFrame
df
# Out:
#                                                Tweets         Label
# 0   ตอนนี้มีไฟไหม้ที่โกดังเก็บฟางในตำบลพุกร่าง อำเ...         fire
# 1         เกิดแผ่นดินไหวขนาดเล็กในพื้นที่จังหวัดแพร่    earthquake
# 2   มีเหตุการณ์กราดยิงเกิดขึ้นที่ห้างสรรพสินค้าพาร...     shooting
# 3           ไฟไหม้โรงงานกิ่งแก้วในจังหวัดสมุทรปราการ          fire
# 4   เกิดแผ่นดินไหวขนาดใหญ่เขย่าจังหวัดเชียงใหม่และ...   earthquake
# 5   เกิดเหตุการณ์กราดยิงในพื้นที่อำเภอสายบุรี จังห...     shooting
# 6         ไฟไหม้บริเวณโรงงานในจังหวัดพระนครศรีอยุธยา          fire
# 7        เกิดแผ่นดินไหวขนาดเล็กในพื้นที่จังหวัดพะเยา    earthquake
# 8   มีเหตุการณ์กราดยิงเกิดขึ้นที่ร้านสะดวกซื้อในจั...     shooting
# 9   ไฟไหม้ป่าในเขตอุทยานแห่งชาติเขาใหญ่ จังหวัดนคร...         fire
# 10  เกิดแผ่นดินไหวในพื้นที่ทะเลอันดามัน ฝั่งจังหวั...   earthquake
# 11               เกิดเหตุกราดยิงในพื้นที่จังหวัดยะลา      shooting
# 12  ไฟไหม้บ้านเรือนประชาชนในชุมชนแออัดแห่งหนึ่งในก...         fire
# ...

# %%
df.to_csv('demo.csv',index=False)

# %%
import pandas as pd

# Create a list of tweets
data = [
    "| #ไฟไหม้พระพุทธบาท โกดังเก่าไฟไหม้แล้วตอนนี้ที่ตำบลพุกร่าง อำเภอพระพุทธบาท | fire |",
    "| #โรงงานกิ่งแก้วไฟไหม้ ไฟไหม้ที่โรงงานกิ่งแก้วแล้วตอนนี้ | fire |",
    "| #ตึกถล่มราชบุรี ที่ราชบุรีมีตึกถล่มลงมาแล้ว | earthquake |",
    "| #แผ่นดินไหว #เชียงใหม่ #แพร่ แผ่นดินไหวที่แพร่ตอนนี้ | earthquake |",
    "| #แผ่นดินไหว #ลอง #แพร่ แผ่นดินไหวที่ลองตอนนี้ | earthquake |",
    "| #พารากอน #siamparagon #สยามพารากอน #กราดยิง #กราดยิงพารากอน มีการกราดยิงกันที่พารากอน | shooting |",
    "| #กราดยิงสายบุรี มีการกราดยิงกันที่สายบุรี | shooting |",
    "| #ระเบิดจะนะ #นิคมลาดกระบังไฟไหม้ #ไฟไหม้โรงงานกิ่งแก้ว #ไฟไหม้พระพุทธบาท #กราดยิงสายบุรี #CPTTP #NoCPTPP เห็นข่าวหรือแฮชแท็กเหล่านี้แล้วช่วยกันติดตาม | shooting |",
    "| #ไฟไหม้ห้างเซ็นทรალเวิลด์ ตอนนี้มีไฟไหม้ที่ห้างเซ็นทรัลเวิลด์ | fire |",
    "| #ไฟไหม้ #โรงพยาบาลพระมงกุฎเกล้า ตอนนี้มีไฟไหม้ที่โรงพยาบาลพระมงกุฎเกล้า | fire |",
    "| #แผ่นดินไหว #เชียงราย #พะเยา มีแผ่นดินไหวที่เชียงรายและพะเยา | earthquake |",
    "| #แผ่นดินไหว #กาญจนบุรี #ราชบุรี มีแผ่นดินไหวที่กาญจนบุรีและราชบุรี | earthquake |",
    "| #แผ่นดินไหว #สุราษฎร์ธานี #ระนอง มีแผ่นดินไหวที่สุราษฎร์ธานีและระนอง | earthquake |",
    "| #กราดยิง #โรงเรียนประถมศึกษาบ้านโคกเตียน มีการกราดยิงที่โรงเรียนประถมศึกษาบ้านโคกเตียน | shooting |",
    "| #กราดยิง #ห้างเซ็นทรัลชลบุรี มีการกราดยิงที่ห้างเซ็นทรัลชลบุรี | shooting |",
    "| #กราดยิง #วัดปัญญานันทาราม มีการกราดยิงที่วัดปัญญานันทาราม | shooting |",
    "| #ไฟไหม้ #ตลาดบางแค มีไฟไหม้ที่ตลาดบางแค | fire |",
    "| #ไฟไหม้ #ตลาดสำเพ็ง มีไฟไหม้ที่ตลาดสำเพ็ง | fire |",
    "| #ไฟไหม้ #โรงแรมเอราวัณ มีไฟไหม้ที่โรงแรมเอราวัณ | fire |",
    "| #แผ่นดินไหว #นครราชสีมา #บุรีรัมย์ มีแผ่นดินไหวที่นครราชสีมาและบุรีรัมย์ | earthquake |",
    "| #แผ่นดินไหว #ตรัง #กระบี่ มีแผ่นดินไหวที่ตรังและกระบี่ | earthquake |",
    "| #แผ่นดินไหว #สตูล #สงขลา มีแผ่นดินไหวที่สตูลและสงขลา | earthquake |",
    "| #กราดยิง #โรงเรียนอนุบาลหนองบัวลำภู มีการกราดยิงที่โรงเรียนอนุบาลหนองบัวลำภู | shooting |",
    "| #กราดยิง #ห้างโลตัสพระราม 4 มีการกราดยิงที่ห้างโลตัสพระราม 4 | shooting |",
    "| #กราดยิง #วัดร่องขุ่น มีการกราดยิงที่วัดร่องขุ่น | shooting |",
    "| #ไฟไหม้ #โกดังบางนา มีไฟไหม้ที่โกดังบางนา | fire |",
    "| #ไฟไหม้ #โรงงานน้ำตาลสุโขทัย มีไฟไหม้ที่โรงงานน้ำตาลสุโขทัย | fire

# %%
import pandas as pd

# Create a list of tweets
data = [
    "#ไฟไหม้พระพุทธบาท โกดังเก่าไฟไหม้แล้วตอนนี้ที่ตำบลพุกร่าง อำเภอพระพุทธบาท | fire |",
    "#โรงงานกิ่งแก้วไฟไหม้ ไฟไหม้ที่โรงงานกิ่งแก้วแล้วตอนนี้ | fire |",
    "#ตึกถล่มราชบุรี ที่ราชบุรีมีตึกถล่มลงมาแล้ว | earthquake |",
    "#แผ่นดินไหว #เชียงใหม่ #แพร่ แผ่นดินไหวที่แพร่ตอนนี้ | earthquake |",
    "#แผ่นดินไหว #ลอง #แพร่ แผ่นดินไหวที่ลองตอนนี้ | earthquake |",
    "#พารากอน #siamparagon #สยามพารากอน #กราดยิง #กราดยิงพารากอน มีการกราดยิงกันที่พารากอน | shooting |",
    "#กราดยิงสายบุรี มีการกราดยิงกันที่สายบุรี | shooting |",
    "#ระเบิดจะนะ #นิคมลาดกระบังไฟไหม้ #ไฟไหม้โรงงานกิ่งแก้ว #ไฟไหม้พระพุทธบาท #กราดยิงสายบุรี #CPTTP #NoCPTPP เห็นข่าวหรือแฮชแท็กเหล่านี้แล้วช่วยกันติดตาม | fire |",
    "#ไฟไหม้ห้างเซ็นทรัลเวิลด์ ตอนนี้มีไฟไหม้ที่ห้างเซ็นทรัลเวิลด์ | fire |",
    "#ไฟไหม้ #โรงพยาบาลพระมงกุฎเกล้า ตอนนี้มีไฟไหม้ที่โรงพยาบาลพระมงกุฎเกล้า | fire |",
    "#แผ่นดินไหว #เชียงราย #พะเยา มีแผ่นดินไหวที่เชียงรายและพะเยา | earthquake |",
    "#แผ่นดินไหว #กาญจนบุรี #ราชบุรี มีแผ่นดินไหวที่กาญจนบุรีและราชบุรี | earthquake |",
    "#แผ่นดินไหว #สุราษฎร์ธานี #ระนอง มีแผ่นดินไหวที่สุราษฎร์ธานีและระนอง | earthquake |",
    "#กราดยิง #โรงเรียนประถมศึกษาบ้านโคกเตียน มีการกราดยิงที่โรงเรียนประถมศึกษาบ้านโคกเตียน | shooting |",
    "#กราดยิง #ห้างเซ็นทรัลชลบุรี มีการกราดยิงที่ห้างเซ็นทรัลชลบุรี | shooting |",
    "#กราดยิง #วัดปัญญานันทาราม มีการกราดยิงที่วัดปัญญานันทาราม | shooting |",
    "#ไฟไหม้ #ตลาดบางแค มีไฟไหม้ที่ตลาดบางแค | fire |",
    "#ไฟไหม้ #ตลาดสำเพ็ง มีไฟไหม้ที่ตลาดสำเพ็ง | fire |",
    "#ไฟไหม้ #โรงแรมเอราวัณ มีไฟไหม้ที่โรงแรมเอราวัณ | fire |",
    "#แผ่นดินไหว #นครราชสีมา #บุรีรัมย์ มีแผ่นดินไหวที่นครราชสีมาและบุรีรัมย์ | earthquake |",
    "#แผ่นดินไหว #ตรัง #กระบี่ มีแผ่นดินไหวที่ตรังและกระบี่ | earthquake |",
    "#แผ่นดินไหว #สตูล #สงขลา มีแผ่นดินไหวที่สตูลและสงขลา | earthquake |",
    "#กราดยิง #โรงเรียนอนุบาลหนองบัวลำภู มีการกราดยิงที่โรงเรียนอนุบาลหนองบัวลำภู | shooting |",
    "#กราดยิง #ห้างโลตัสพระราม 4 มีการกราดยิงที่ห้างโลตัสพระราม 4 | shooting |",
    "#กราดยิง #วัดร่องขุ่น มีการกราดยิงที่วัดร่องขุ่น | shooting |",
    "#ไฟไหม้ #โกดังบางนา มีไฟไหม้ที่โกดังบางนา | fire |",
    "#ไฟไหม้ #โรงงานน้ำตาลสุโขทัย มีไฟไหม้ที่โรงงานน้ำตาลสุโขทัย | fire |"
]

# # Split each tweet into a list using the pipe delimiter
tweets = []
for tweet in data:
    tweets.append(tweet.split("|"))

# Create a DataFrame from the list of tweets
df = pd.DataFrame(tweets, columns=["tweet", "label",'no'])

# Print the DataFrame
df
# Out:
#                                                 tweet         label no
# 0   #ไฟไหม้พระพุทธบาท โกดังเก่าไฟไหม้แล้วตอนนี้ที่...         fire
# 1   #โรงงานกิ่งแก้วไฟไหม้ ไฟไหม้ที่โรงงานกิ่งแก้วแ...         fire
# 2        #ตึกถล่มราชบุรี ที่ราชบุรีมีตึกถล่มลงมาแล้ว    earthquake
# 3   #แผ่นดินไหว #เชียงใหม่ #แพร่ แผ่นดินไหวที่แพร่...   earthquake
# 4      #แผ่นดินไหว #ลอง #แพร่ แผ่นดินไหวที่ลองตอนนี้    earthquake
# 5   #พารากอน #siamparagon #สยามพารากอน #กราดยิง #ก...     shooting
# 6          #กราดยิงสายบุรี มีการกราดยิงกันที่สายบุรี      shooting
# 7   #ระเบิดจะนะ #นิคมลาดกระบังไฟไหม้ #ไฟไหม้โรงงาน...         fire
# 8   #ไฟไหม้ห้างเซ็นทรัลเวิลด์ ตอนนี้มีไฟไหม้ที่ห้า...         fire
# 9   #ไฟไหม้ #โรงพยาบาลพระมงกุฎเกล้า ตอนนี้มีไฟไหม้...         fire
# 10  #แผ่นดินไหว #เชียงราย #พะเยา มีแผ่นดินไหวที่เช...   earthquake
# 11  #แผ่นดินไหว #กาญจนบุรี #ราชบุรี มีแผ่นดินไหวที...   earthquake
# 12  #แผ่นดินไหว #สุราษฎร์ธานี #ระนอง มีแผ่นดินไหวท...   earthquake
# ...

# %%
df

# %%
df2 = pd.concat([df2,df])
df2 = p
# Out:
#                                                 tweet         label   no  \
# 0   #โรงงานไฟไหม้ ล่าสุดเกิดเหตุเพลิงไหม้โรงงานแห่...         fire
# 1   #ไฟไหม้ป่า ล่าสุดเกิดเหตุไฟไหม้ป่าใน [อุทยานแห...         fire
# 2   #ไฟไหม้บ้าน ล่าสุดเกิดเหตุไฟไหม้บ้านใน [ชุมชน]...         fire
# 3   #แผ่นดินไหว ล่าสุดเกิดเหตุแผ่นดินไหวใน [จังหวั...   earthquake
# 4   #แผ่นดินไหวรุนแรง ล่าสุดเกิดเหตุแผ่นดินไหวรุนแ...   earthquake
# ..                                                ...           ...  ...
# 28                                                NaN           NaN  NaN
# 29                                                NaN           NaN  NaN
# 30                                                NaN           NaN  NaN
# 31                                                NaN           NaN  NaN
# 32                                                NaN           NaN  NaN
#
#                               Tweets     Label
# 0                                NaN       NaN
# ...

# %%
df3 = pd.concat([df2,df])

# %%
import pandas as pd

def g(df):
  df1 = df.iloc[:-33].copy()
  df2 = df.tail(33).copy()
  return df1, df2
df1, df2 = g(df3)

# %%
df1.columns
# Out:
# Index(['tweet', 'label', 'no', 'Tweets', 'Label'], dtype='object')

# %%
# df1 = df1.drop(['no',	'Tweets',	'Label'], axis=1)
df1
# Out:
#                                                 tweet         label
# 0   #โรงงานไฟไหม้ ล่าสุดเกิดเหตุเพลิงไหม้โรงงานแห่...         fire
# 1   #ไฟไหม้ป่า ล่าสุดเกิดเหตุไฟไหม้ป่าใน [อุทยานแห...         fire
# 2   #ไฟไหม้บ้าน ล่าสุดเกิดเหตุไฟไหม้บ้านใน [ชุมชน]...         fire
# 3   #แผ่นดินไหว ล่าสุดเกิดเหตุแผ่นดินไหวใน [จังหวั...   earthquake
# 4   #แผ่นดินไหวรุนแรง ล่าสุดเกิดเหตุแผ่นดินไหวรุนแ...   earthquake
# ..                                                ...           ...
# 22  #กราดยิง #โรงเรียนอนุบาลหนองบัวลำภู มีการกราดย...     shooting
# 23  #กราดยิง #ห้างโลตัสพระราม 4 มีการกราดยิงที่ห้า...     shooting
# 24  #กราดยิง #วัดร่องขุ่น มีการกราดยิงที่วัดร่องขุ่น      shooting
# 25         #ไฟไหม้ #โกดังบางนา มีไฟไหม้ที่โกดังบางนา          fire
# 26  #ไฟไหม้ #โรงงานน้ำตาลสุโขทัย มีไฟไหม้ที่โรงงาน...         fire
#
# [117 rows x 2 columns]

# %%
df2.columns
# Out:
# Index(['Tweets', 'Label'], dtype='object')

# %%
# df2 = df2.drop(['tweet', 'label', 'no',], axis=1)
df2 = df2.rename(columns={'Tweets': 'tweet', 'Label': 'label'})
df2
# Out:
#                                     tweet     label
# 0                   วันนี้ฝนตกหนักมากเลย    normal
# 1                    ช่วงนี้อากาศร้อนจัง    normal
# 2   เมื่อวานไปกินข้าวกับเพื่อนมา สนุกมาก    normal
# 3              กำลังดูหนังอยู่สนุกมากเลย    normal
# 4                เพิ่งตื่นนอน ง่วงนอนมาก    normal
# 5            กินข้าวเสร็จแล้ว ง่วงนอนเลย    normal
# 6                     กำลังจะไปทำงานแล้ว    normal
# 7               เพิ่งเลิกงานเมื่อยมากเลย    normal
# 8                   กำลังจะไปกินข้าวเย็น    normal
# 9        กินข้าวเย็นเสร็จแล้ว ง่วงนอนเลย    normal
# 10                      กำลังจะไปนอนแล้ว    normal
# 11                  วันนี้ฝนตกหนักมากเลย    normal
# 12                   ช่วงนี้อากาศร้อนจัง    normal
# 13  เมื่อวานไปกินข้าวกับเพื่อนมา สนุกมาก    normal
# 14             กำลังดูหนังอยู่สนุกมากเลย    normal
# 15               เพิ่งตื่นนอน ง่วงนอนมาก    normal
# 16           กินข้าวเสร็จแล้ว ง่วงนอนเลย    normal
# ...

# %%
# test_set = pd.concat([df1,df2]).sample(frac=1)
test_set = test_set.drop_duplicates()

# %%
test_set.to_csv('test.csv')
