# %% [markdown]
# #Import Data

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
fire_list = ['#ไฟไหม้', '#นิคมลาดกระบัง until:2021-07-07 AND min_retweets:50 OR min_faves:50', '#โรงงานกิ่งแก้วไฟไหม้ until:2021-07-05 AND min_retweets:50 OR min_faves:50',
             '#ไฟไหม้โรงงานลาดกระบัง until:2021-07-07 AND min_retweets:50 OR min_faves:50', '#ไฟไหม้โรงงานกิ่งแก้ว until:2021-07-07 AND min_retweets:50 OR min_faves:50',
             '#ไฟไหม้พระพุทธบาท until:2021-07-07 AND min_retweets:50 OR min_faves:50', 'ไฟไหม้สระบุรี', '#ตลาดบ้านแพ้ว until:2021-08-01 AND min_retweets:50 OR min_faves:50',
             '#ไฟไหม้ผับชลบุรี until:2022-08-05 AND min_retweets:50 OR min_faves:50']
shooting_list = ['#กราดยิง min_retweets:50 OR min_faves:50', '#กราดยิงสายบุรี until:2021-07-07 AND min_retweets:50 OR min_faves:50', '#พารากอน  until:2023-10-04 AND min_retweets:50 OR min_faves:50',
                 '#กราดยิงพารากอน until:2023-10-04 AND min_retweets:50 OR min_faves:50', '#กราดยิงอุบล until:2022-08-04 AND min_retweets:50 OR min_faves:50', 'กราดยิงหนองบัวลําภู',
                 '#กราดยิงโคราช since:2020-02-08 AND min_retweets:50 OR min_faves:50']
eth_list = ['#แผ่นดินไหว', '#ไต้หวัน', '#พังงา แผ่นดินไหว', '#เชียงใหม่ แผ่นดินไหว', '#ปาย แผ่นดินไหว', '#แม่ฮ่องสอน แผ่นดินไหว', '#แพร่ แผ่นดินไหว']
oth_list = ['#23point5EP7', 'ONGSASUN BEGIN AGAIN', '#ขวัญฤทัยEP4', '#FWDMusicLiveFestXPROXIE', '#WeAreSeriesLIVE', 'WE ARE PRESSTOUR', '#Flex1045xJuniorFluke', 'Meow Noeul Live',
            'NANON FWD SONGKRAN', 'WE HEART NOONPRAEWA', 'Patrick Early Summer', 'INFINITY LOVE TO ENGFA19', '#เป๊ปซี่เจมีไนน์โฟร์ทEP2', '#TheKingdomsConcert', '#itsMagentaxNegac',
            '#MalinxGlutaCollagen','#BABII247concertLIVE', '#DeerSecretxJames', '#150KGrowthWithKongjiro', '#โต๊ะนี้นุ๊กจอง']

# %%
f_name = fire_list + shooting_list + eth_list

# %%
import os

# Define the folder path
folder_path = "/content/drive/MyDrive/traindata"

# Get all file names in the folder
f_name = os.listdir(folder_path)

# Print all file names
print(f_name)
# Out:
# ['#แผ่นดินไหว.csv', '#ไต้หวัน.csv', '#พังงา.csv', '#เชียงใหม่.csv', '#ปาย.csv', '#แม่ฮ่องสอน.csv', '#แพร่.csv', '#ไฟไหม้.csv', '#นิคมลาดกระบัง.csv', '#โรงงานกิ่งแก้วไฟไหม้.csv', '#ไฟไหม้โรงงานลาดกระบัง.csv', '#ไฟไหม้โรงงานกิ่งแก้ว.csv', '#ไฟไหม้พระพุทธบาท.csv', 'ไฟไหม้สระบุรี.csv', '#ตลาดบ้านแพ้ว.csv', '#ไฟไหม้ผับชลบุรี.csv', '#กราดยิง.csv', '#กราดยิงสายบุรี.csv', '#พารากอน.csv', '#กราดยิงพารากอน.csv', '#กราดยิงอุบล.csv', 'กราดยิงหนองบัวลําภู.csv', 'กราดยิงโคราช.csv', 'เทอร์มินอล.csv', '#THETOYS.csv', '#PingXMintSpecialEdition.csv', '#CoverbySnackxชอบนอน.csv', '#LoveSiblingsEP8.csv', '#MySiblingsRomanceEP8.csv', '#อะไรที่ทําให้โฟร์ทยิ้มได้.csv', '#TimeToPlaySongkran.csv', '#1monthwithDICE.csv', '#เลขเด็ดแม่หนูเล็ก.csv', '#ออฟกัน247พรุ่งนี้มาแน่.csv', '#ปณิดา.csv', '#น้องใบบุญ.csv', '#PSYCHICFEVERxFWD.csv', '#GeminiFourth.csv', '#23point5EP7.csv', 'ONGSASUN.csv', '#ขวัญฤทัยEP4.csv', '#FWDMusicLiveFestXPROXIE.csv', '#WeAreSeriesLIVE.csv', '#Flex1045xJuniorFluke.csv', 'Meow.csv', 'NANON
# ...

# %%
folder_path = "/content/drive/MyDrive/traindata"

# Create an empty dictionary to store dataframes
dataframes = {}
for file in f_name:
  df = pd.read_csv(folder_path + '/' + file)

  # Remove the '.csv' extension from the filename (optional)
  dataframe_name = file[:-4]

  # Store the dataframe in the dictionary with filename as key
  dataframes[dataframe_name] = df

# Now you have a dictionary named 'dataframes' where keys are filenames (without extension) and values are corresponding dataframes
print(dataframes.keys())  # Print all dataframe names
# Out:
# dict_keys(['#แผ่นดินไหว', '#ไต้หวัน', '#พังงา', '#เชียงใหม่', '#ปาย', '#แม่ฮ่องสอน', '#แพร่', '#ไฟไหม้', '#นิคมลาดกระบัง', '#โรงงานกิ่งแก้วไฟไหม้', '#ไฟไหม้โรงงานลาดกระบัง', '#ไฟไหม้โรงงานกิ่งแก้ว', '#ไฟไหม้พระพุทธบาท', 'ไฟไหม้สระบุรี', '#ตลาดบ้านแพ้ว', '#ไฟไหม้ผับชลบุรี', '#กราดยิง', '#กราดยิงสายบุรี', '#พารากอน', '#กราดยิงพารากอน', '#กราดยิงอุบล', 'กราดยิงหนองบัวลําภู', 'กราดยิงโคราช', 'เทอร์มินอล', '#THETOYS', '#PingXMintSpecialEdition', '#CoverbySnackxชอบนอน', '#LoveSiblingsEP8', '#MySiblingsRomanceEP8', '#อะไรที่ทําให้โฟร์ทยิ้มได้', '#TimeToPlaySongkran', '#1monthwithDICE', '#เลขเด็ดแม่หนูเล็ก', '#ออฟกัน247พรุ่งนี้มาแน่', '#ปณิดา', '#น้องใบบุญ', '#PSYCHICFEVERxFWD', '#GeminiFourth', '#23point5EP7', 'ONGSASUN', '#ขวัญฤทัยEP4', '#FWDMusicLiveFestXPROXIE', '#WeAreSeriesLIVE', '#Flex1045xJuniorFluke', 'Meow', 'NANON', 'WE', 'Patrick', 'INFINITY', '#เป๊ปซี่เจมีไนน์โฟร์ทEP2', '#TheKingdomsConcert', '#itsMagentaxNegac', '#MalinxGlutaCollagen', '#BABII247concertLIVE', '#DeerSecretxJames
# ...

# %%
import pandas as pd

# Assuming you have a dictionary named 'dataframes' containing dataframes with keys as mentioned

eth_list = ['#แผ่นดินไหว', '#ไต้หวัน', '#พังงา', '#เชียงใหม่', '#ปาย', '#แม่ฮ่องสอน', '#แพร่']
fire_list = ["#ไฟไหม้", "#นิคมลาดกระบัง", "#โรงงานกิ่งแก้วไฟไหม้", "#ไฟไหม้โรงงานลาดกระบัง", "#ไฟไหม้โรงงานกิ่งแก้ว", "#ไฟไหม้พระพุทธบาท", "ไฟไหม้สระบุรี", "#ตลาดบ้านแพ้ว", "#ไฟไหม้ผับชลบุรี"]
shooting_list = ["#กราดยิง", "#กราดยิงสายบุรี", "#พารากอน", "#กราดยิงพารากอน", "#กราดยิงอุบล", "กราดยิงหนองบัวลําภู", "กราดยิงโคราช"]

# Initialize empty dataframes
eth_df = pd.DataFrame()
fire_df = pd.DataFrame()
shooting_df = pd.DataFrame()
other_df = pd.DataFrame()

# Iterate through the dictionary, selecting dataframes based on keys
for key, dataframe in dataframes.items():
  if key in eth_list:
    eth_df = pd.concat([eth_df, dataframe])  # Use concat for appending
  elif key in fire_list:
    fire_df = pd.concat([fire_df, dataframe])
  elif key in shooting_list:
    shooting_df = pd.concat([shooting_df, dataframe])
  elif key in oth_list:
    other_df = pd.concat([other_df, dataframe])

# Now you have separate dataframes: eth_df, fire_df, and shooting_df

# %%
other_df
# Out:
#     Unnamed: 0  conversation_id_str                      created_at  \
# 0            0  1781326573960073423  Fri Apr 19 14:18:45 +0000 2024
# 1            1  1781333416098529622  Fri Apr 19 14:45:56 +0000 2024
# 2            2  1781330887184970098  Fri Apr 19 14:35:53 +0000 2024
# 3            3  1781319087664062907  Fri Apr 19 13:49:00 +0000 2024
# 4            4  1781332636893384786  Fri Apr 19 14:42:50 +0000 2024
# ..         ...                  ...                             ...
# 15          15  1781330684201804169  Fri Apr 19 14:35:05 +0000 2024
# 16          16  1781316658730340518  Fri Apr 19 13:39:21 +0000 2024
# 17          17  1781326122640462109  Fri Apr 19 14:16:57 +0000 2024
# 18          18  1781310711525949721  Fri Apr 19 13:15:43 +0000 2024
# 19          19  1781313037598883945  Fri Apr 19 13:24:58 +0000 2024
#
#     favorite_count                                          full_text  \
# 0              367  กำลังภูมิใจกับสีลิปที่ให้องศาไปเมื่อคืน อยู่ๆเ...
# ...

# %% [markdown]
# #Cleaning Data

# %%
def del_dup(df):
  df.drop_duplicates(subset='full_text', inplace=True)
  return df

# %%
def del_col(df):
  # Get all column names
  col_name_list = ['conversation_id_str',	'created_at',	'favorite_count',	'full_text',	'id_str', 'quote_count',	'reply_count', 'retweet_count',	'user_id_str']
  all_cols = list(df.columns)

  # Get columns to delete (excluding those to keep)
  cols_to_delete = [col for col in all_cols if col not in col_name_list]

  # Drop unwanted columns (in-place modification)
  df.drop(cols_to_delete, axis=1, inplace=True)
  return df

# %%
def add_tag(df,tag):
  df["disaster"] = tag
  return df

# %%
import re

def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')  # Compiled URL pattern
    return url_pattern.sub('', text)  # Efficiently replace URLs with empty string
def rm_url(df):
  df['full_text'] = df['full_text'].apply(remove_urls)
  return df

# %%
other_df
# Out:
#     Unnamed: 0  conversation_id_str                      created_at  \
# 0            0  1781326573960073423  Fri Apr 19 14:18:45 +0000 2024
# 1            1  1781333416098529622  Fri Apr 19 14:45:56 +0000 2024
# 2            2  1781330887184970098  Fri Apr 19 14:35:53 +0000 2024
# 3            3  1781319087664062907  Fri Apr 19 13:49:00 +0000 2024
# 4            4  1781332636893384786  Fri Apr 19 14:42:50 +0000 2024
# ..         ...                  ...                             ...
# 15          15  1781330684201804169  Fri Apr 19 14:35:05 +0000 2024
# 16          16  1781316658730340518  Fri Apr 19 13:39:21 +0000 2024
# 17          17  1781326122640462109  Fri Apr 19 14:16:57 +0000 2024
# 18          18  1781310711525949721  Fri Apr 19 13:15:43 +0000 2024
# 19          19  1781313037598883945  Fri Apr 19 13:24:58 +0000 2024
#
#     favorite_count                                          full_text  \
# 0              367  กำลังภูมิใจกับสีลิปที่ให้องศาไปเมื่อคืน อยู่ๆเ...
# ...

# %%
del_dup(fire_df)
del_dup(shooting_df)
del_dup(eth_df)
del_dup(other_df)
del_col(fire_df)
del_col(shooting_df)
del_col(eth_df)
del_col(other_df)
add_tag(fire_df,'fire')
add_tag(shooting_df,'shooting')
add_tag(eth_df,'earthquake')
add_tag(other_df,'normal')
rm_url(fire_df)
rm_url(shooting_df)
rm_url(eth_df)
rm_url(other_df)
# Out:
#     conversation_id_str                      created_at  favorite_count  \
# 0   1781326573960073423  Fri Apr 19 14:18:45 +0000 2024             367
# 1   1781333416098529622  Fri Apr 19 14:45:56 +0000 2024              29
# 2   1781330887184970098  Fri Apr 19 14:35:53 +0000 2024             186
# 3   1781319087664062907  Fri Apr 19 13:49:00 +0000 2024             199
# 4   1781332636893384786  Fri Apr 19 14:42:50 +0000 2024              62
# ..                  ...                             ...             ...
# 15  1781330684201804169  Fri Apr 19 14:35:05 +0000 2024               2
# 16  1781316658730340518  Fri Apr 19 13:39:21 +0000 2024               9
# 17  1781326122640462109  Fri Apr 19 14:16:57 +0000 2024               9
# 18  1781310711525949721  Fri Apr 19 13:15:43 +0000 2024              24
# 19  1781313037598883945  Fri Apr 19 13:24:58 +0000 2024              14
#
#                                             full_text               id_str  \
# ...

# %%
data1 = pd.concat([fire_df, shooting_df, eth_df, other_df, df])
# data1

# %%
def get_text_disaster_tuples(df):
  text_disaster_tuples = [(text, disaster) for text, disaster in zip(df['full_text'], df['disaster'])]

  return text_disaster_tuples
text_disaster_list = get_text_disaster_tuples(data1.copy())
text_disaster_list

# %%
data1
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 0     1775751722641797132  Thu Apr 04 05:06:17 +0000 2024             158
# 1     1775179584352501767  Tue Apr 02 15:12:48 +0000 2024              10
# 2     1776207885535756508  Fri Apr 05 11:18:54 +0000 2024              22
# 3     1776362065717850139  Fri Apr 05 21:31:34 +0000 2024               3
# 4     1776372064653578554  Fri Apr 05 22:11:18 +0000 2024              14
# ...                   ...                             ...             ...
# 1678  1786830006477537706  Sat May 04 18:47:25 +0000 2024               0
# 1679  1786830504635023484  Sat May 04 18:49:24 +0000 2024               0
# 1680  1786818581549998574  Sat May 04 18:02:01 +0000 2024               0
# 1681  1786820621432959260  Sat May 04 18:10:08 +0000 2024               0
# 1682  1786810620358344761  Sat May 04 17:30:23 +0000 2024               0
#
#                                               full_text               id_str  \
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/add_data.csv')
# data = get_text_disaster_tuples(df)

# %% [markdown]
# # Training

# %%
pip install pythainlp
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 28.8 MB/s eta 0:00:00
# ...

# %%
from pythainlp.classify import GzipModel

# %%
model = GzipModel(training_data=text_disaster_list)

# %%
print(model.predict("แผ่นดินไหว", k=1))
# Out:
# earthquake

# %% [markdown]
# # Saving model

# %%
import pickle

# %%
import pickle

# Assuming your model creation step is done and 'model' contains the trained model

# Open a file in binary write mode for pickling
with open("disaster_classifier.sav", "wb") as f:
    # Use pickle.dump to serialize the model and write it to the file
    pickle.dump(model, f)

print("Model saved as disaster_classifier.sav")
# Out:
# Model saved as disaster_classifier.sav

# %%
# model.Cx2_list

# %%
from transformers import AutoModelForTokenClassification
from pythainlp.tokenize import word_tokenize  # Assuming pythainlp is installed

# Model name (replace with yours if different)
model_name = "pythainlp/thainer-corpus-v2-base-model"

# Load tokenizer and model
tokenizer = AutoModelForTokenClassification.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/2.27k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/419M [00:00<?, ?B/s]

# %%
from pythainlp.phayathaibert.core import NamedEntityTagger

tagger = NamedEntityTagger()
tagger.get_ner("ทดสอบนายปวริศ เรืองจุติโพธิ์พานจากประเทศไทย")
# Out:
# tokenizer_config.json:   0%|          | 0.00/527 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.26M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/15.0k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/364 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.4M [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# tokenizer_config.json:   0%|          | 0.00/144k [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.26M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/15.0k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/364 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/2.18k [00:00<?, ?B/s]
# ...

# %%
test = pd.read_csv('/content/drive/MyDrive/traindata/#กราดยิงสายบุรี.csv')
tagger.get_ner(test['full_text'][12])
# Out:
# [('ที่', 'LOCATION'),
#  ('ปัตตานี', 'LOCATION'),
#  ('กราดยิง', 'LOCATION'),
#  ('สาย', 'LOCATION'),
#  ('บุรี', 'LOCATION'),
#  ('จะ', 'LOCATION'),
#  ('นะ', 'LOCATION'),
#  ('ลาดกระบัง', 'LOCATION'),
#  ('โรงงาน', 'LOCATION'),
#  ('กิ่งแก้ว', 'LOCATION')]

# %%
tagger.get_ner(test['full_text'][0])[0][1]

# %%
# p = []
# for i in test['full_text']:
#   p.append(tagger.get_ner(i))

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-b6beac939548> in <cell line: 2>()
#       1 from collections import Counter
# ----> 2 print(Counter(p))
#
# /usr/lib/python3.10/collections/__init__.py in __init__(self, iterable, **kwds)
#     575         '''
#     576         super().__init__()
# --> 577         self.update(iterable, **kwds)
#     578
#     579     def __missing__(self, key):
#
# /usr/lib/python3.10/collections/__init__.py in update(self, iterable, **kwds)
#     668                     super().update(iterable)
#     669             else:
# --> 670                 _count_elements(self, iterable)
#     671         if kwds:
#     672             self.update(kwds)
#
# TypeError: unhashable type: 'list'

# %%
import pandas as pd

# Assuming you have a DataFrame 'test' with a column 'full_text' containing tweets

def find_locations(text, tagger):
  """
  Extracts locations from a given text using the provided NER tagger.

  Args:
      text (str): The text to analyze.
      tagger (object): The NER tagger object with a get_ner() method.

  Returns:
      list: A list of locations found in the text.
  """
  entities = tagger.get_ner(text)
  locations = [entity[0] for entity in entities if entity[1] == 'FACILITY']  # Filter for 'FACILITY' category
  return locations

# Apply the function to each row in the 'full_text' column
test['locations'] = test['full_text'].apply(lambda text: find_locations(text, tagger))

# Print the DataFrame with the new 'locations' column
test
# Out:
#     Unnamed: 0  conversation_id_str                      created_at  \
# 0            0  1412431919426453504  Tue Jul 06 15:23:05 +0000 2021
# 1            1  1412433776206966788  Tue Jul 06 15:30:28 +0000 2021
# 2            2  1412426642543239169  Tue Jul 06 15:02:07 +0000 2021
# 3            3  1412425951263199242  Tue Jul 06 14:59:23 +0000 2021
# 4            4  1412427874003468300  Tue Jul 06 15:07:01 +0000 2021
# 5            5  1412427569832603672  Tue Jul 06 15:05:48 +0000 2021
# 6            6  1412467770705334284  Tue Jul 06 17:45:33 +0000 2021
# 7            7  1412429357495177220  Tue Jul 06 15:12:55 +0000 2021
# 8            8  1412426988929884167  Tue Jul 06 15:03:30 +0000 2021
# 9            9  1412430701245263877  Tue Jul 06 15:18:15 +0000 2021
# 10          10  1412429063801610244  Tue Jul 06 15:11:45 +0000 2021
# 11          11  1412430869147521025  Tue Jul 06 15:18:55 +0000 2021
# 12          12  1412426460439121935  Tue Jul 06 15:01:24 +0000 2021
# ...

# %%
from pythainlp.phayathaibert.core import NamedEntityTagger
tagger = NamedEntityTagger()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/527 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.26M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/15.0k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/364 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.4M [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ...

# %%
tagger.get_ner('น้ำตาลกราดยิงบนปากน้ำพะเยา')
# Out:
# [('', 'PERSON'), ('ปากน้ํา', 'LOCATION'), ('พะเยา', 'LOCATION')]

# %%
for i in tagger.get_ner('กราดยิงบนปากน้ำ พะเยา'):
  if i[1] == 'LOCATION':
    print(i[0])
    print(i[1])
# Out:
# ปากน้ํา
# LOCATION
# พะเยา
# LOCATION

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
pip freeze > requirements.txt

# %%
import pickle

# Assuming your model creation step is done and 'model' contains the trained model

# Open a file in binary write mode for pickling
with open("get_location.sav", "wb") as f:
    # Use pickle.dump to serialize the model and write it to the file
    pickle.dump(tagger, f)

print("Model saved as get_location.sav")
# Out:
# Model saved as get_location.sav

# %%
import pickle
getlocation_model = pickle.load(open('get_location.sav','rb'))
print(getlocation_model.get_ner('น้ำกินไก่ที่ปากน้ำ'))
# Out:
# [('ปากน้ํา', 'LOCATION')]
